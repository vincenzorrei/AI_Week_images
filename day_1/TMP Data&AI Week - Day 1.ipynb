# %% [markdown]
# ![table of content](https://github.com/vincenzorrei/AI_Week_images/raw/main/day_1/TableOfContent.png)

# %% [markdown]
# # 1) Google Colab

# %% [markdown]
# ![colab](https://github.com/vincenzorrei/AI_Week_images/raw/main/day_1/Colab.png)

# %% [markdown]
# # 2) Introduzione a Python

# %% [markdown]
# ## 2.1) Primi passi

# %% [markdown]
# ### 🖨️ `print()` – Stampare a schermo

# %% [markdown]
# La funzione `print()` serve per **visualizzare un messaggio** o il contenuto di una variabile nel terminale o nell'output.
#
# ➡️ Sintassi: `print(valore_o_testo)`

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# ### 🧠 Assegnazione a variabili

# %% [markdown]
# In Python possiamo **salvare un valore** all'interno di una **variabile** usando il simbolo `=`.
#
# Una variabile è come una **scatola con un'etichetta**: ci metti dentro un valore e puoi riutilizzarlo più volte.
#
# ➡️ Sintassi: `nome_variabile = valore`

# %%
nome = "Vincenzo"
età = 25

# %%
print(nome)
# Out:
# Vincenzo

# %% [markdown]
# ## 2.2) Tipi

# %% [markdown]
# ### 🔢 `int` – Numeri interi

# %% [markdown]
# Un tipo di dato che rappresenta **numeri interi**, positivi o negativi, **senza parte decimale**.
#
# Esempi: `5`, `-2`, `0`, `123456`

# %%
a = 123
print("Il valore è:", a)
print("Tipo:", type(a))
# Out:
# Il valore è: 123
# Tipo: <class 'int'>

# %%
# Somma
x = 1
y = 2
somma = x + y
print("La somma è:", somma)
# Out:
# La somma è: 3

# %% [markdown]
# ### 🌊 `float` – Numeri decimali

# %% [markdown]
# Il tipo `float` rappresenta **numeri con la virgola**, utili per misure, percentuali, e calcoli più precisi.
#
# Esempi: `3.14`, `-0.5`, `2.0`

# %%
pi = 3.14
print("Il valore è:", pi)
print("Tipo:", type(pi))
# Out:
# Il valore è: 3.14
# Tipo: <class 'float'>

# %%
# Operazioni matematiche (moltiplicazione)
prezzo = 3.5
quantità = 5
totale = prezzo * quantità
print("Totale:", totale)
# Out:
# Totale: 17.5

# %% [markdown]
# ### 📝 `str` – Stringhe di testo

# %% [markdown]
# Le stringhe (`str`) rappresentano **sequenze di caratteri**, cioè **testo**. Si scrivono tra **virgolette**.
#
# Esempi: `"ciao"`, `'Python'`, `"123"`

# %%
messaggio = "Ciao a tutti"
print(messaggio)
print("Tipo:", type(messaggio))
# Out:
# Ciao a tutti
# Tipo: <class 'str'>

# %%
# Concatenazione
nome = "Alice"
saluto = "Ciao, " + nome + "!" # "Ciao, Alice!"
print(saluto)
# Out:
# Ciao, Alice!

# %% [markdown]
# ### 🔘 `bool` – Valori booleani

# %% [markdown]
# Un tipo di dato logico con soli due possibili valori: **`True` (vero)** o **`False` (falso)**. Molto usato in **condizioni e controlli**.
#
# Esempi: `True`, `False`

# %%
attivo = True
print("Stato:", attivo)
print("Tipo:", type(attivo))
# Out:
# Stato: True
# Tipo: <class 'bool'>

# %%
# Check
età = 20
maggiorenne = età == 18
print("Sei maggiorenne?", maggiorenne)
# Out:
# Sei maggiorenne? False

# %%
# And
print(True and True)
# Out:
# True

# %%
# True and
print(True and False)
# Out:
# False

# %% [markdown]
# ### 📚 `list` – Collezioni ordinate di elementi

# %% [markdown]
# Una `list` è una **sequenza ordinata** di elementi, che possono essere di qualsiasi tipo. Si definisce con le **parentesi quadre `[]`**.
#
# È **modificabile** (mutable): si possono aggiungere, rimuovere o cambiare elementi.
#
# Esempi: `[1, 2, 3]`, `["a", "b", "c"]`

# %%
frutti = ["mela", "banana", "kiwi"] # lista con mela banana e kiwi
print(frutti)
print("Tipo:", type(frutti))
# Out:
# ['mela', 'banana', 'kiwi']
# Tipo: <class 'list'>

# %%
# Aggiungere elementi
numeri = [10, 20, 30]
numeri.append(40) # aggiungere elementi
print("Lista aggiornata:", numeri)
# Out:
# Lista aggiornata: [10, 20, 30, 40]

# %%
# Accedere ad elementi
primo_numero = numeri[0]
print("Primo elemento:", primo_numero)
print("Secondo elemento:", numeri[1])
# Out:
# Primo elemento: 10
# Secondo elemento: 20

# %%
# Rimuovere elementi
numeri.remove(30) # rimuovere elementi
print("Lista aggiornata:", numeri)
# Out:
# Lista aggiornata: [20, 40]

# %%
# Check presenza di elementi
presente = 'mela' in frutti # la mela è negli elementi?
print(presente)
# Out:
# True

# %%
# Lista di liste
bibite = ['acqua', 'birra', 'vino']
spesa = [frutti, bibite]
print(spesa)
# Out:
# [['mela', 'banana', 'kiwi'], ['acqua', 'birra', 'vino']]

# %%
# Estensione di liste
altra_spesa = frutti + bibite
print(altra_spesa)
# Out:
# ['mela', 'banana', 'kiwi', 'acqua', 'birra', 'vino']

# %%
# Importazione libreria
import random

# Campionamento
elemento = random.choice(altra_spesa) # random choice
print(elemento)
# Out:
# acqua

# %% [markdown]
# ### 🧩 `if` – Esegui qualcosa **solo se** una condizione è vera

# %% [markdown]
# Il blocco `if` serve per controllare se una condizione è **vera** (`True`). Se lo è, il codice al suo interno viene eseguito.
#
# ➡️ Sintassi:
# ```python
# if condizione:
#     istruzioni
# ```

# %%
eta = 17

# %%
if eta >= 18:
    print("Sei maggiorenne.")
print('Stampato?')
# Out:
# Stampato?

# %% [markdown]
# # 3) The Game

# %% [markdown]
# ![Locandina](https://github.com/vincenzorrei/AI_Week_images/raw/main/day_1/Donald.png)

# %% [markdown]
# ## 🎯 Gioco Finale – *Fake Fake News*
#
# Topics: **variabili, liste, funzioni, input e condizioni**.
#
# ### 👀 Obiettivo del gioco
#
# Abbiamo preparato **due liste di frasi**:
#
# - Una contiene **fake news realmente dette da Donald Trump**.
# - L'altra contiene **fake fake news**, cioè frasi inventate che suonano come dichiarazioni plausibili, ma che **Trump non ha mai detto**.
#
# Il nostro compito è cercare di **indovinare** quali frasi sono autentiche *Trump-style fake news*, e quali invece sono completamente inventate.
#
# ### 🧠 Come funziona
#
# 1. Una frase verrà mostrata a caso.
# 2. Tu dovrai rispondere scrivendo `s` (sì) se pensi che **Trump abbia detto** quella frase, oppure `n` (no) se pensi che **non l’abbia detta**.

# %% [markdown]
# ### Le liste
# ```python
# vere = ['blablalba', 'blablabla', ... , 'blablabla']
# false = ['nguenguengue', 'nguenguengue', ... , 'nguenguengue']
# ```

# %%
vere = [
    "Il cambiamento climatico è una bufala inventata dai cinesi.",
    "Barack Obama non è nato negli Stati Uniti.",
    "Il vaccino MMR causa l'autismo.",
    "Il padre di Ted Cruz era coinvolto nell'assassinio di JFK.",
    "Milioni di voti illegali sono stati espressi nelle elezioni del 2016.",
    "Il COVID-19 scomparirà da solo.",
    "Iniettare disinfettante può curare il COVID-19.",
    "Il Messico pagherà per il muro al confine.",
    "La mia inaugurazione ha avuto la più grande affluenza di pubblico nella storia.",
    "L'amministrazione Obama ha spiato la mia campagna elettorale.",
    "L'Iran ha ricevuto 150 miliardi di dollari in contanti dall'accordo nucleare.",
    "Il NAFTA è il peggior accordo commerciale mai stipulato dagli USA.",
    "La NATO è obsoleta.",
    "L'ISIS è stato sconfitto al 100%.",
    "L'economia americana non è mai stata così forte.",
    "La Cina sta pagando le tariffe imposte dagli USA.",
    "Abbiamo un sistema sanitario che copre tutti a costi inferiori.",
    "La mia riforma fiscale è la più grande riduzione fiscale della storia americana.",
    "La crisi degli oppioidi è in diminuzione.",
    "Il sistema elettorale è truccato contro di me.",
    "L'uragano Dorian colpirà l'Alabama.",
    "Abbiamo un deficit commerciale con il Canada.",
    "La costruzione del muro al confine è già iniziata.",
    "C'è una crisi umanitaria al confine meridionale.",
    "Il voto per corrispondenza causa frodi diffuse.",
    "Le carovane di migranti sono un'invasione organizzata.",
    "Il tasso di criminalità negli USA è in aumento.",
    "Ho firmato il Music Modernization Act.",
    "I bambini sono quasi immuni al COVID-19.",
    "Il Congo sta liberando prigionieri per inviarli negli Stati Uniti."
]

# Lista di notizie inventate plausibili nel contesto dello stile comunicativo di Trump
false = [
    "Ho scoperto una cura miracolosa per il COVID-19.",
    "Gli Stati Uniti hanno il sistema sanitario migliore del mondo grazie a me.",
    "Sono stato nominato per il Premio Nobel per la Pace più volte di qualsiasi altro presidente.",
    "Ho creato più posti di lavoro di qualsiasi altro presidente nella storia.",
    "La mia amministrazione ha eliminato completamente il debito nazionale.",
    "Sono il presidente più popolare nella storia degli Stati Uniti.",
    "Ho reso l'America completamente indipendente dal punto di vista energetico.",
    "La mia amministrazione ha costruito più infrastrutture di qualsiasi altra.",
    "Ho negoziato l'accordo commerciale più vantaggioso di sempre.",
    "Grazie a me, l'America è rispettata più che mai sulla scena mondiale.",
    "Ho reso l'America il paese più sicuro del mondo.",
    "La mia amministrazione ha scoperto prove definitive di vita extraterrestre.",
    "Ho reso l'America il leader mondiale nella tecnologia 5G.",
    "Ho eliminato completamente la povertà negli Stati Uniti.",
    "La mia amministrazione ha reso l'America il paese più innovativo del mondo.",
    "Ho creato il programma spaziale più avanzato della storia.",
    "Grazie a me, l'America ha il sistema educativo numero uno al mondo.",
    "Ho reso l'America il paese più pulito ambientalmente.",
    "La mia amministrazione ha scoperto una nuova fonte di energia illimitata.",
    "Ho reso l'America il paese con la maggiore aspettativa di vita.",
    "Ho eliminato completamente la criminalità negli Stati Uniti.",
    "La mia amministrazione ha reso l'America il paese più felice del mondo.",
    "Ho scoperto il segreto per la pace mondiale.",
    "Grazie a me, l'America ha la tecnologia più avanzata nel settore sanitario.",
    "Ho reso l'America il paese più avanzato nella ricerca scientifica.",
    "La mia amministrazione ha reso l'America il leader mondiale nella produzione manifatturiera.",
    "Ho creato il sistema di trasporti più efficiente del mondo.",
    "Grazie a me, l'America ha il sistema fiscale più equo.",
    "Ho reso l'America il paese più trasparente e onesto.",
    "La mia amministrazione ha scoperto il segreto per l'eterna giovinezza."
]

# %% [markdown]
# ## Creazione del gioco

# %%
mista = vere + false

# %%
variabile = input("Inserisci qualcosa: ")
print(variabile)
# Out:
# Inserisci qualcosa: TRUMP
# TRUMP

# %%
domanda_casuale = random.choice(mista)
mista.remove(domanda_casuale)

risposta = input(domanda_casuale + " (s/n): ")

# Caso 1: Abbiamo INDOVINATO, è una vera fake news
if risposta == "s" and domanda_casuale in vere:
    print("Oooh nooo! L'ha fatto ancora")

# Caso 2: Abbiamo INDOVINATO, non è stata detta da Trump
if risposta == "n" and domanda_casuale in false:
    print('Fiuuu. Era una Fake Fake News')

# Caso 3: Abbiamo SBAGLIATO, non è una fake news
if risposta == "s" and domanda_casuale in false:
    print("Malpensante! Non è nel suo stile")

# Caso 4: Abbiamo SBAGLAITO, era una fake news
if risposta == "n" and domanda_casuale in vere:
    print("Hai sottovalutato Donald!")
# Out:
# La mia amministrazione ha scoperto prove definitive di vita extraterrestre. (s/n): n
# Fiuuu. Era una Fake Fake News

# %% [markdown]
# # 4) Esercizi

# %%
# Inserisci un valore con input() e scopri che tipo di dato è.
valore = # YOUR CODE HERE
print("Il valore è:", valore)
print("Il tipo di dato è:", type(valore))

# %%
# Lista di frutti preferiti
frutti = ["mela", "banana", "kiwi", "pera"]

# Seleziona il primo elemento della lista frutti
primo_elemento = # YOUR CODE HERE

print("Il primo frutto è:", primo_elemento)

# %%
# Crea una lista vuota
animali = # YOUR CODE HERE

# Inserisci degli animali con input()
animale1 = # YOUR CODE HERE
animale2 = # YOUR CODE HERE

# Appendi queste osservazioni alla lista vuota
# YOUR CODE HERE
# YOUR CODE HERE

print("Lista degli animali:", animali)
